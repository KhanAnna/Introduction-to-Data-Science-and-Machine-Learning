# %% [markdown]
# # Фильтрация данных
# В этом уроке:
# 1. pandas.DataFrame.query
# 2. pandas.DataFrame.select_dtypes
# 3. При работе с pandas series для логического И нужно использовать & вместо уже знакомого and

# %%
# Импорт сторонних библиотек
import pandas as pd
import numpy as np

# %%
# Считываем учебный файл с данными студентов
students = pd.read_csv("https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv")

# %%
# Первые и последние 5 строк датасета
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Описательная статистика по всему датасету, исключая NaN значения
students.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
# Вывод строк со значением female в столбце gender
students[students.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Оценка по матетематике (math score) у женщин (gender='female')
students.loc[students.gender == 'female', ['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 5    female          71
# 6    female          88
# ..      ...         ...
# 993  female          62
# 995  female          88
# 997  female          59
# 998  female          68
# 999  female          77
#
# [518 rows x 2 columns]

# %%
# Средняя оценка по математике
mean_math_score = students['writing score'].mean()

# %%
# Создание запроса со строками, где пол женский и оценка по математике выше средней
query=(students['math score'] > mean_math_score) & (students['gender']=='female')

# %%
# Вывод строк по запросу
students.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# У какой доли студентов из датасета в колонке lunch указано free/reduced?
x = students[(students.lunch == 'free/reduced')]
x
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
x.size/students.size
# Ответ: 0.355 - доля студентов из датасета со значением free/reduced в колонке lunch
# Out:
# 0.355

# %%
# Описательная статистика по всему датасету, исключая NaN значения
x.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# count      355            355                         355           355
# unique       2              5                           6             1
# top     female        group C                some college  free/reduced
# freq       189            114                          79           355
# mean       NaN            NaN                         NaN           NaN
# std        NaN            NaN                         NaN           NaN
# min        NaN            NaN                         NaN           NaN
# 25%        NaN            NaN                         NaN           NaN
# 50%        NaN            NaN                         NaN           NaN
# 75%        NaN            NaN                         NaN           NaN
# max        NaN            NaN                         NaN           NaN
#
#        test preparation course  math score  reading score  writing score
# ...

# %%
# Смотрим информацию о студентах со стандартным ланчем
y=students[(students.lunch == 'standard')]
y.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count      645            645                         645       645
# unique       2              5                           6         1
# top     female        group C                some college  standard
# freq       329            205                         147       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                      645  645.000000     645.000000     645.000000
# ...

# %%
# отберёт студентов, уровень образования родителей которых бакалавр или магистр
students[students['parental level of education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# ..      ...            ...                         ...           ...
# 957  female        group D             master's degree      standard
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# наблюдения, оценка за математику которых выше 90 и за чтение меньше либо равна 72
students[(students['math score'] > 90) & (students['reading score'] <=72)]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
# Студенты со стандартным ланчем
student_stats.query("lunch == 'standard'")
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
# студенты, не прошедшие тест
students[students['test preparation course'] != 'completed']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Считываем учебный файл по ссылке и сохраняем его в переменную df
df=pd.read_csv('https://stepik.org/media/attachments/course/4852/column_hell.csv')

# %%
# Отбираем колонки, в которых есть '-' в датафрэйме df и сохраняем их в переменную selected_columns
select_columns=df.filter(like='-')
select_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]
